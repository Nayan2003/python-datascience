# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1.	Make the excel sheet with following data:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2.	Make a dataframe named result using this and

# %%
result=pd.read_csv('result.csv')
result
# Out:
#         name  accountancy  english  maths  economics  bisiness studies
# 0   akhilesh           97       36     47         13                34
# 1      ruchi           69       85     86         51                53
# 2     bhawna           19       72     41         53                40
# 3       isha           76       68     46         11                22
# 4     chetan           55       31     56         99                93
# 5      neeti           84       57     68         30                31
# 6   chanchal           18       46     51         63                22
# 7     preeti           93       93     31         93                20
# 8      richa           33       89     55         46                69
# 9     manish           21       27     84         82                96
# 10     karun           13       48     27         26                38

# %% [markdown]
# #### 3.	write the python command for the following

# %%
name=['akhilesh',
'ruchi',
'bhawna',
'isha',
'chetan',
'neeti',
'chanchal',
'preeti',
'richa',
'manish',
'karun'
]

# %%
result.index=name
result.drop('name',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-9fb106c4405d> in <module>()
#       1 result. index=name
# ----> 2 result.drop('name',axis=1,inplace=True)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
result
# Out:
#           accountancy  english  maths  economics  bisiness studies
# akhilesh           97       36     47         13                34
# ruchi              69       85     86         51                53
# bhawna             19       72     41         53                40
# isha               76       68     46         11                22
# chetan             55       31     56         99                93
# neeti              84       57     68         30                31
# chanchal           18       46     51         63                22
# preeti             93       93     31         93                20
# richa              33       89     55         46                69
# manish             21       27     84         82                96
# karun              13       48     27         26                38

# %% [markdown]
# #### 4.	display the row labels, column labels ,shape, size of the data frame and determine whether the data frame or not.

# %%
print('row=',result.index )
# Out:
# row= Index(['akhilesh', 'ruchi', 'bhawna', 'isha', 'chetan', 'neeti', 'chanchal',
#        'preeti', 'richa', 'manish', 'karun'],
#       dtype='object')

# %%
print('column=',result.columns )
# Out:
# column= Index(['accountancy', 'english', 'maths', 'economics', 'bisiness studies'], dtype='object')

# %%
print('shape',result.shape)
# Out:
# shape (11, 5)

# %%
print('size',result.size)
# Out:
# size 55

# %%
type(result)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### 5.	display transpose of the dataframe,1st four rows of data frame , the last three rows of data frame.

# %%
result.T #display transpose of the dataframe
# Out:
#                   akhilesh  ruchi  bhawna  isha  chetan  neeti  chanchal  \
# accountancy             97     69      19    76      55     84        18
# english                 36     85      72    68      31     57        46
# maths                   47     86      41    46      56     68        51
# economics               13     51      53    11      99     30        63
# bisiness studies        34     53      40    22      93     31        22
#
#                   preeti  richa  manish  karun
# accountancy           93     33      21     13
# english               93     89      27     48
# maths                 31     55      84     27
# economics             93     46      82     26
# bisiness studies      20     69      96     38

# %%
result.head(4) #1st four rows of data frame
# Out:
#           accountancy  english  maths  economics  bisiness studies
# akhilesh           97       36     47         13                34
# ruchi              69       85     86         51                53
# bhawna             19       72     41         53                40
# isha               76       68     46         11                22

# %%
result.tail(3)#last three rows of data frame
# Out:
#         accountancy  english  maths  economics  bisiness studies
# richa            33       89     55         46                69
# manish           21       27     84         82                96
# karun            13       48     27         26                38

# %% [markdown]
# #### 6.	arrange the data frame in the ascending order of rows, descending order of row, ascending order of columns, descending order of columns

# %%
result.sort_index(axis=0) #ascending order of rows
# Out:
#           accountancy  english  maths  economics  bisiness studies
# akhilesh           97       36     47         13                34
# bhawna             19       72     41         53                40
# chanchal           18       46     51         63                22
# chetan             55       31     56         99                93
# isha               76       68     46         11                22
# karun              13       48     27         26                38
# manish             21       27     84         82                96
# neeti              84       57     68         30                31
# preeti             93       93     31         93                20
# richa              33       89     55         46                69
# ruchi              69       85     86         51                53

# %%
result.sort_index(ascending=False) #descending order of columns
# Out:
#           accountancy  english  maths  economics  bisiness studies
# ruchi              69       85     86         51                53
# richa              33       89     55         46                69
# preeti             93       93     31         93                20
# neeti              84       57     68         30                31
# manish             21       27     84         82                96
# karun              13       48     27         26                38
# isha               76       68     46         11                22
# chetan             55       31     56         99                93
# chanchal           18       46     51         63                22
# bhawna             19       72     41         53                40
# akhilesh           97       36     47         13                34

# %%
result.sort_index(ascending=False,axis=1)#descending order of columns
# Out:
#           maths  english  economics  bisiness studies  accountancy
# akhilesh     47       36         13                34           97
# ruchi        86       85         51                53           69
# bhawna       41       72         53                40           19
# isha         46       68         11                22           76
# chetan       56       31         99                93           55
# neeti        68       57         30                31           84
# chanchal     51       46         63                22           18
# preeti       31       93         93                20           93
# richa        55       89         46                69           33
# manish       84       27         82                96           21
# karun        27       48         26                38           13

# %% [markdown]
# #### 7.	arrange the data frame in ascending order of marks in math, in descending order of marks in english and economics

# %%
result.sort_values('maths')#ascending order of marks in math
# Out:
#           accountancy  english  maths  economics  bisiness studies
# karun              13       48     27         26                38
# preeti             93       93     31         93                20
# bhawna             19       72     41         53                40
# isha               76       68     46         11                22
# akhilesh           97       36     47         13                34
# chanchal           18       46     51         63                22
# richa              33       89     55         46                69
# chetan             55       31     56         99                93
# neeti              84       57     68         30                31
# manish             21       27     84         82                96
# ruchi              69       85     86         51                53

# %%
result.sort_values(['english','economics'],ascending=False)
# Out:
#           accountancy  english  maths  economics  bisiness studies
# preeti             93       93     31         93                20
# richa              33       89     55         46                69
# ruchi              69       85     86         51                53
# bhawna             19       72     41         53                40
# isha               76       68     46         11                22
# neeti              84       57     68         30                31
# karun              13       48     27         26                38
# chanchal           18       46     51         63                22
# akhilesh           97       36     47         13                34
# chetan             55       31     56         99                93
# manish             21       27     84         82                96

# %% [markdown]
# #### 8.	to display max , min ,sum ,mean, mode ,var ,std deviation of all the columns, for columns accountancy and English ,for all the rows ,for the row with index isha ,for the row with index ruchi and manish

# %%
result.max()
# Out:
# accountancy         97
# english             93
# maths               86
# economics           99
# bisiness studies    96
# dtype: int64

# %%
result.min()
# Out:
# accountancy         13
# english             27
# maths               27
# economics           11
# bisiness studies    20
# dtype: int64

# %%
result.sum()
# Out:
# accountancy         578
# english             652
# maths               592
# economics           567
# bisiness studies    518
# dtype: int64

# %%
result.mean()
# Out:
# accountancy         52.545455
# english             59.272727
# maths               53.818182
# economics           51.545455
# bisiness studies    47.090909
# dtype: float64

# %%
result.mode()
# Out:
#     accountancy  english  maths  economics  bisiness studies
# 0            13       27     27         11              22.0
# 1            18       31     31         13               NaN
# 2            19       36     41         26               NaN
# 3            21       46     46         30               NaN
# 4            33       48     47         46               NaN
# 5            55       57     51         51               NaN
# 6            69       68     55         53               NaN
# 7            76       72     56         63               NaN
# 8            84       85     68         82               NaN
# 9            93       89     84         93               NaN
# 10           97       93     86         99               NaN

# %%
result.var()
# Out:
# accountancy         1068.872727
# english              561.218182
# maths                367.363636
# economics            930.872727
# bisiness studies     757.090909
# dtype: float64

# %%
result.std()
# Out:
# accountancy         32.693619
# english             23.690044
# maths               19.166733
# economics           30.510207
# bisiness studies    27.515285
# dtype: float64

# %%
result[['accountancy','english']].max()#accountancy and English
# Out:
# accountancy    97
# english        93
# dtype: int64

# %%
result[['accountancy','english']].min()#accountancy and English
# Out:
# accountancy    13
# english        27
# dtype: int64

# %%
result[['accountancy','english']].sum()#accountancy and English
# Out:
# accountancy    578
# english        652
# dtype: int64

# %%
result[['accountancy','english']].mean()#accountancy and English
# Out:
# accountancy    52.545455
# english        59.272727
# dtype: float64

# %%
result[['accountancy','english']].mode()#accountancy and English
# Out:
#     accountancy  english
# 0            13       27
# 1            18       31
# 2            19       36
# 3            21       46
# 4            33       48
# 5            55       57
# 6            69       68
# 7            76       72
# 8            84       85
# 9            93       89
# 10           97       93

# %%
result[['accountancy','english']].var()#accountancy and English
# Out:
# accountancy    1068.872727
# english         561.218182
# dtype: float64

# %%
result[['accountancy','english']].std()#accountancy and English
# Out:
# accountancy    32.693619
# english        23.690044
# dtype: float64

# %%
#for the row with index isha for the row with index ruchi and manish
#max
result.loc[['isha','ruchi','manish']].max(numeric_only=True,axis=1)
# Out:
# isha      76
# ruchi     86
# manish    96
# dtype: int64

# %%
#for the row with index isha for the row with index ruchi and manish
#max
result.loc[['isha','ruchi','manish']].min(numeric_only=True,axis=1)
# Out:
# isha      11
# ruchi     51
# manish    21
# dtype: int64

# %%
#for the row with index isha for the row with index ruchi and manish
#max
result.loc[['isha','ruchi','manish']].sum(numeric_only=True,axis=1)
# Out:
# isha      223
# ruchi     344
# manish    310
# dtype: int64

# %%
#for the row with index isha for the row with index ruchi and manish
#max
result.loc[['isha','ruchi','manish']].mean(numeric_only=True,axis=1)
# Out:
# isha      44.6
# ruchi     68.8
# manish    62.0
# dtype: float64

# %%
#for the row with index isha for the row with index ruchi and manish
#max
result.loc[['isha','ruchi','manish']].mode(numeric_only=True,axis=1)
# Out:
#          0   1   2   3   4
# isha    11  22  46  68  76
# ruchi   51  53  69  85  86
# manish  21  27  82  84  96

# %%
#for the row with index isha for the row with index ruchi and manish
#max
result.loc[['isha','ruchi','manish']].var(numeric_only=True,axis=1)
# Out:
# isha       793.8
# ruchi      281.2
# manish    1236.5
# dtype: float64

# %%
#for the row with index isha for the row with index ruchi and manish
#max
result.loc[['isha','ruchi','manish']].std(numeric_only=True,axis=1)
# Out:
# isha      28.174457
# ruchi     16.769019
# manish    35.163902
# dtype: float64
