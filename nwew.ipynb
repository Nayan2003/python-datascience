# %% [markdown]
# ## Practical No.5

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### 1.Create a data frame which is consist of column name as ename, edpt,age,basicsal, add 5 rows .

# %%
name=['nayan','sahil','afrin','arpit','anjali']
edpt=['programming','hr','hr','programming','fin']
age=[21,50,50,20,20]
basicsal=[100000,200000,120000,540000,641000]
comp={'ename':name,'edpt':edpt,'age':age,'basicsal':basicsal}
df=pd.DataFrame(comp)
df
# Out:
#     ename         edpt  age  basicsal
# 0   nayan  programming   21    100000
# 1   sahil           hr   50    200000
# 2   afrin           hr   50    120000
# 3   arpit  programming   20    540000
# 4  anjali          fin   20    641000

# %% [markdown]
# #### 2.CHANGE THE INDEX of the dataframe 501,502,…

# %%
df=pd.DataFrame(comp,index=[501,502,503,504,505])
df
# Out:
#       ename         edpt  age  basicsal
# 501   nayan  programming   21    100000
# 502   sahil           hr   50    200000
# 503   afrin           hr   50    120000
# 504   arpit  programming   20    540000
# 505  anjali          fin   20    641000

# %% [markdown]
# #### a)add one column with edesig

# %%
edesig=['programmer','manager','manager','programmer','programmer']
df['edesig']=edesig
df
# Out:
#       ename         edpt  age  basicsal      edesig
# 501   nayan  programming   21    100000  programmer
# 502   sahil           hr   50    200000     manager
# 503   afrin           hr   50    120000     manager
# 504   arpit  programming   20    540000  programmer
# 505  anjali          fin   20    641000  programmer

# %% [markdown]
# #### 3.add one row using loc method ,and one using append method

# %%
df.loc[506] = ['shrutika','fin','25','68000','programmer'] 
df
# Out:
#         ename         edpt age basicsal      edesig
# 501     nayan  programming  21   100000  programmer
# 502     sahil           hr  50   200000     manager
# 503     afrin           hr  50   120000     manager
# 504     arpit  programming  20   540000  programmer
# 505    anjali          fin  20   641000  programmer
# 506  shrutika          fin  25    68000  programmer

# %%
df=df.append({'ename':'tehseen','edpt':'hr','age':24,'basicsal':4520021,'edesig':'programmer'},ignore_index=True)
df.index=[501,502,503,504,505,506,507]
df
# Out:
#         ename         edpt age basicsal      edesig
# 501     nayan  programming  21   100000  programmer
# 502     sahil           hr  50   200000     manager
# 503     afrin           hr  50   120000     manager
# 504     arpit  programming  20   540000  programmer
# 505    anjali          fin  20   641000  programmer
# 506  shrutika          fin  25    68000  programmer
# 507   tehseen           hr  24  4520021  programmer

# %% [markdown]
# #### 4.modify the values of index number 501 with new values

# %%
df.loc[501]=['nano','programming',24,875460,'programmer']
df
# Out:
#         ename         edpt age basicsal      edesig
# 501      nano  programming  24   875460  programmer
# 502     sahil           hr  50   200000     manager
# 503     afrin           hr  50   120000     manager
# 504     arpit  programming  20   540000  programmer
# 505    anjali          fin  20   641000  programmer
# 506  shrutika          fin  25    68000  programmer
# 507   tehseen           hr  24  4520021  programmer

# %% [markdown]
# #### 5.drop the row with index number 503

# %%
df=df.drop(503,axis=0)
df
# Out:
#         ename         edpt age basicsal      edesig
# 501      nano  programming  24   875460  programmer
# 502     sahil           hr  50   200000     manager
# 504     arpit  programming  20   540000  programmer
# 505    anjali          fin  20   641000  programmer
# 506  shrutika          fin  25    68000  programmer
# 507   tehseen           hr  24  4520021  programmer

# %% [markdown]
# #### 6.add column hra where hra is 2%of basic salary

# %%
df['hra']=df['basicsal']*0.02
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1008         try:
# -> 1009             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1010         except TypeError:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1029             with np.errstate(all='ignore'):
# -> 1030                 return na_op(lvalues, rvalues)
#    1031         except Exception:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1019                 mask = notna(x)
# -> 1020                 result[mask] = op(x[mask], y)
#    1021
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-159-54844e5b2b04> in <module>()
# ----> 1 df['hra']=df['basicsal']*0.02
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1064             rvalues = rvalues.values
#    1065
# -> 1066         result = safe_na_op(lvalues, rvalues)
#    1067         return construct_result(left, result,
#    1068                                 index=left.index, name=res_name, dtype=None)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1032             if is_object_dtype(lvalues):
#    1033                 return libalgos.arrmap_object(lvalues,
# -> 1034                                               lambda x: op(x, rvalues))
#    1035             raise
#    1036
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1032             if is_object_dtype(lvalues):
#    1033                 return libalgos.arrmap_object(lvalues,
# -> 1034                                               lambda x: op(x, rvalues))
#    1035             raise
#    1036
#
# TypeError: can't multiply sequence by non-int of type 'float'
